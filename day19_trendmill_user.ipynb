# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('treadmil-users.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.sample(5)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80    TM498   19    Male         14        Single      3        3   31836
# 13    TM195   22  Female         14        Single      3        3   35247
# 45    TM195   28  Female         16     Partnered      2        3   52302
# 143   TM798   23    Male         16        Single      4        5   58516
# 127   TM498   34    Male         15        Single      3        3   67083
#
#      Miles
# 80      64
# 13      75
# 45      66
# 143    140
# 127     85

# %%
cat_cols=['Product','Gender','MaritalStatus']

# %%
for col in cat_cols:
    print(col)
    print('*'*15)
    print(data[col].value_counts())
    print('')
# Out:
# Product
# ***************
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64
#
# Gender
# ***************
# Male      104
# Female     76
# Name: Gender, dtype: int64
#
# MaritalStatus
# ***************
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
sns.set_style('whitegrid')

# %%
for col in cat_cols:
    sns.countplot(data=data,x=col)
    plt.title(col)
    plt.show()

# %% [markdown]
# EDA - Exploratory Data Analysis
#     1.Univariate(single variable)
#     2.Bivariable(two variable)
#     3.Multivariable(multiple variable)

# %%
cat_cols=['Product','Gender','MaritalStatus']
num_cols=['Age','Fitness','Usage','Education','Income','Miles']

# %%
import seaborn as sns

# %%
from random import random,choice
random()
# Out:
# 0.9263281405327949

# %%
p_list=[ 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
]

# %%
######univariate analysis

# %%
# Categorical Data
for col in cat_cols:
    plt.figure(figsize=(10,3))
    plt.subplot(1,2,1)
    sns.countplot(data=data,x=col,palette=choice(p_list))
    plt.title(col)
    plt.subplot(1,2,2)
    data[col].value_counts().plot.pie(autopct='%1.1f%%',figszie=(8,4))
    plt.show()

#Numerical Data
for col in num_cols:
    color=[random(),random(),random()]
    fig = plt.figure(figsize=(10,3)) 
    fig.suptitle(col) 
    plt.subplot(1,3,1) 
    sns.distplot(data[col],color=[30/255,100/255,57/255])
    plt.subplot(1,3,2)
    sns.boxplot(data=data,x=col)
    plt.subplot(1,3,3)
    sns.violinplot(data=data,x=col)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\harsh\OneDrive\Desktop\ml\day19_trendmill_user.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a>     plt.title(col)
#       <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a>     plt.subplot(1,2,2)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>     data[col].value_counts().plot.pie(autopct='%1.1f%%',figszie=(8,4))
#       <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a>     plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> #Numerical Data
#
# File c:\Users\harsh\anaconda3\lib\site-packages\pandas\plotting\_core.py:1584, in PlotAccessor.pie(self, **kwargs)
#    1578 if (
#    1579     isinstance(self._parent, ABCDataFrame)
#    1580     and kwargs.get("y", None) is None
#    1581     and not kwargs.get("subplots", False)
#    1582 ):
#    1583     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1584 return self(kind="pie", **kwargs)
#
# File c:\Users\harsh\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\harsh\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\harsh\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File c:\Users\harsh\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1666, in PiePlot._make_plot(self)
#    1664 else:
#    1665     blabels = None
# -> 1666 results = ax.pie(y, labels=blabels, **kwds)
#    1668 if kwds.get("autopct", None) is not None:
#    1669     patches, texts, autotexts = results
#
# File c:\Users\harsh\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# TypeError: pie() got an unexpected keyword argument 'figszie'

# %%
data['Income'].nunique()
# Out:
# 62

# %%
data.shape
# Out:
# (180, 9)

# %%
for col in data.columns:
    print('-')
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -

# %% [markdown]
# #Bivariate Analysis
#
#
# boxplot-cat,num
#
# jointplot-num,num
# scatterplot-num,num(X)
# Regplot-num,num(X)
#
# violinplot-cat,num
# swaramplot-cat,num(X)
#
# lineplot-num,num
#
# pointplot-num,num
#
# kdeplot-num,num
# rugplot-num,num(X)
#
# barplot-cat,num(X)

# %%
for col in cat_cols:
    for ncol in num_cols:
        
     plt.figure(figsize=(10,3)) 
     plt.suptitle(f'(col) vs (ncol)')
     plt.subplot(1,3,1) 
     sns.boxplot(data= data,x=col,y=ncol,palette=choice(p_list))
     plt.subplot(1,3,2)
     sns.violinplot(data=data,x=col,y=ncol,palette=choice(p_list))
     plt.subplot(1,3,3)
     sns.barplot(data=data,x=col,y=ncol,palette=choice(p_list))
     plt.show()

# %%
for col in num_cols:
    for ncol in num_cols:
        if col == ncol:
           continue
        plt.figure(figsize=(10,3))
        plt.figure(1,2,1)
        sns.jointplot(data=data,x=col1,y=col2,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\harsh\OneDrive\Desktop\ml\day19_trendmill_user.ipynb Cell 22 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> plt.figure(figsize=(10,3))
#       <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X30sZmlsZQ%3D%3D?line=5'>6</a> plt.figure(1,2,1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ml/day19_trendmill_user.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a> sns.jointplot(data=data,x=col1,y=col2,)
#
# NameError: name 'col1' is not defined
